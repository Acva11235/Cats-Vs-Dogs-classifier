# %%
# !pip install tensorflow==2.10
# Out:
# ^C

# %%
# !pip list
# Out:
# Package                      Version
# ---------------------------- ---------
# absl-py                      2.0.0
# anyio                        3.6.2
# argon2-cffi                  21.3.0
# argon2-cffi-bindings         21.2.0
# arrow                        1.2.3
# asttokens                    2.2.1
# astunparse                   1.6.3
# attrs                        23.1.0
# backcall                     0.2.0
# beautifulsoup4               4.12.2
# bleach                       6.0.0
# cachetools                   5.3.2
# certifi                      2022.12.7
# cffi                         1.15.1
# charset-normalizer           3.3.0
# colorama                     0.4.6
# comm                         0.1.3
# contourpy                    1.1.0
# cycler                       0.11.0
# debugpy                      1.6.7
# decorator                    5.1.1
# defusedxml                   0.7.1
# dm-tree                      0.1.8
# docutils                     0.20.1
# ...
